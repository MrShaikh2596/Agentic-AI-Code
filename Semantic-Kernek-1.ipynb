# %%
# !pip install -r '/content/drive/MyDrive/Colab Notebooks/requirements.txt'
# Out:
# ...
#   Using cached semantic_kernel-1.20.0-py3-none-any.whl.metadata (5.3 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 2.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 674.0/674.0 kB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.6/187.6 kB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.7/103.7 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.9/198.9 kB 17.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.2/113.2 kB 9.7 MB/s eta 0:00:00
# ...

# %%
#Setting API keys
import os
from google.colab import userdata as us
#os.environ["HUGGING_FACE_API_TOKEN"] = us.get("HUGGING_FACE_API_TOKEN")
os.environ["ANTHROPIC_API_KEY"] = us.get("ANTHROPIC_API_KEY")

# %%
#Importing Libraries
import semantic_kernel as sk
from semantic_kernel.connectors.ai.hugging_face  import HuggingFaceTextCompletion

# %%
an_kernel = sk.Kernel()
chat_servide = HuggingFaceTextCompletion(ai_model_id  = 'HuggingFaceTB/SmolLM2-360M-Instruct',task='text-generation')
an_kernel.add_service("chat_completion",chat_servide)
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/724M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.76k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/801k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/655 [00:00<?, ?B/s]
# Device set to use cpu
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-871dad5e7e27> in <cell line: 0>()
#       1 an_kernel = sk.Kernel()
#       2 chat_servide = HuggingFaceTextCompletion(ai_model_id  = 'HuggingFaceTB/SmolLM2-360M-Instruct',task='text-generation')
# ----> 3 an_kernel.add_service("chat_completion",chat_servide)
#
# ...
